# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# Given the above transaction data t1 to t7, assume: minsup = 30%, minconf = 80%, find
# all the frequent itemset, calculate support

# %%
dataset = [['Beef', 'Chicken', 'Milk'],
           ['Beef', 'Cheese'],
           ['Cheese', 'Boots'],
           ['Beef', 'Chicken', 'Cheese'],
           ['Beef', 'Chicken', 'Clothes', 'Cheese', 'Milk'],
           ['Chicken','Clothes','Milk'],
           ['Chicken','Milk','Clothes']]

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df, min_support=0.3, use_colnames=True)
frequent_itemsets
# Out:
#      support                  itemsets
# 0   0.571429                    (Beef)
# 1   0.571429                  (Cheese)
# 2   0.714286                 (Chicken)
# 3   0.428571                 (Clothes)
# 4   0.571429                    (Milk)
# 5   0.428571            (Beef, Cheese)
# 6   0.428571           (Beef, Chicken)
# 7   0.428571        (Clothes, Chicken)
# 8   0.571429           (Milk, Chicken)
# 9   0.428571           (Clothes, Milk)
# 10  0.428571  (Clothes, Milk, Chicken)

# %% [markdown]
# generate association rules from the itemset,
# calculate support and confidence

# %%
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.79999)
# Out:
#           antecedents      consequents  antecedent support  \
# 0           (Clothes)        (Chicken)            0.428571
# 1              (Milk)        (Chicken)            0.571429
# 2           (Chicken)           (Milk)            0.714286
# 3           (Clothes)           (Milk)            0.428571
# 4     (Clothes, Milk)        (Chicken)            0.428571
# 5  (Clothes, Chicken)           (Milk)            0.428571
# 6           (Clothes)  (Milk, Chicken)            0.428571
#
#    consequent support   support  confidence  lift  leverage  conviction
# 0            0.714286  0.428571         1.0  1.40  0.122449         inf
# 1            0.714286  0.571429         1.0  1.40  0.163265         inf
# 2            0.571429  0.571429         0.8  1.40  0.163265    2.142857
# 3            0.571429  0.428571         1.0  1.75  0.183673         inf
# 4            0.714286  0.428571         1.0  1.40  0.122449         inf
# 5            0.571429  0.428571         1.0  1.75  0.183673         inf
# 6            0.571429  0.428571         1.0  1.75  0.183673         inf
